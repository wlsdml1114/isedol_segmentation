# %%
import os
import subprocess



for i in range(8):

	command = "ffmpeg -i %s -acodec copy  -ss 00:00:%02d -to 00:00:%02d %s"%('/home/jini1114/git/mir-svc/data/raw_data/IU/1.wav',i*5, (i+1)*5, '/home/jini1114/git/mir-svc/data/raw_data/IU/'+str(i)+'_1.wav')
	subprocess.call(command, shell=True)
	command = "ffmpeg -i %s -acodec copy  -ss 00:00:%02d -to 00:00:%02d %s"%('/home/jini1114/git/mir-svc/data/raw_data/VIICHAN/1.wav',i*5, (i+1)*5, '/home/jini1114/git/mir-svc/data/raw_data/VIICHAN/'+str(i)+'_1.wav')
	subprocess.call(command, shell=True)
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/jini1114/.conda/envs/mdx-net --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
# ...

# %%
"test %d"%(1)

for i in range(8):
    print(i)
print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 7
